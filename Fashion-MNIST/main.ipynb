# %%
# ! pip install tensorflow

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,AveragePooling2D,MaxPooling2D, Flatten, Dense, Dropout, Activation, BatchNormalization
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.manifold import LocallyLinearEmbedding
np.set_printoptions(precision=4)

# %% [markdown]
# ## Import tha Fashion MNIST dataset

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
(train_images, valid_images) = train_images[:50000], train_images[50000:]
(train_labels, valid_labels) = train_labels[:50000], train_labels[50000:]

# %%
print(f"trianing set: {train_images.shape}") # 60,000 images in the training set, each image represented as 28x28 px
print(f"validation set: {valid_images.shape}") # 10,000 images in the validation set, each image represented as 28x28 px
print(f"test set: {test_images.shape}") # 10,000 images in the test set, each image represented as 28x28 px
# Out:
# trianing set: (50000, 28, 28)
# validation set: (10000, 28, 28)
# test set: (10000, 28, 28)

# %% [markdown]
# ## Preprocess the data
# The pixel values fall in the range of 0 to 255, so i scale values to range 0 to 1 before feeding them to neural networ model. To do so, I divided the values by 255.
#
# I dispalyed the first 25 images from the training set and the label name below in order to verify that the data is in the correct format to build and train the network.

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Building the model
# The basic building block of a neural network is the layer. Layers extract representations from the data fed into them.

# %%
model = tf.keras.Sequential()
# Must define the input shape in the first layer of the neural network
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Take a look at the model summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        320
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        8224
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten_1 (Flatten)         (None, 1568)              0
#
#  dense_3 (Dense)             (None, 256)               401664
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
chekcpoint = ModelCheckpoint('best_model.hdf5',verbose=1,save_best_only=True, monitor = 'val_accuracy')

hist = model.fit(train_images,train_labels, batch_size=128,
          callbacks=[chekcpoint],
          steps_per_epoch=train_images.shape[0] // 128, 
          epochs=50,
          verbose=2,
          validation_data=(valid_images, valid_labels)
         )
# Out:
# Epoch 1/50
# /home/miriam/.local/lib/python3.10/site-packages/keras/backend.py:5585: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Epoch 1: val_accuracy improved from -inf to 0.80970, saving model to best_model.hdf5
# 390/390 - 55s - loss: 1.4375 - accuracy: 0.6590 - val_loss: 0.5282 - val_accuracy: 0.8097 - 55s/epoch - 141ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.80970 to 0.84220, saving model to best_model.hdf5
# 390/390 - 50s - loss: 0.5979 - accuracy: 0.7769 - val_loss: 0.4343 - val_accuracy: 0.8422 - 50s/epoch - 129ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.84220 to 0.85960, saving model to best_model.hdf5
# 390/390 - 57s - loss: 0.5187 - accuracy: 0.8056 - val_loss: 0.3821 - val_accuracy: 0.8596 - 57s/epoch - 146ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.85960 to 0.86840, saving model to best_model.hdf5
# 390/390 - 54s - loss: 0.4718 - accuracy: 0.8249 - val_loss: 0.3511 - val_accuracy: 0.8684 - 54s/epoch - 137ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.86840 to 0.87640, saving model to best_model.hdf5
# 390/390 - 53s - loss: 0.4358 - accuracy: 0.8390 - val_loss: 0.3347 - val_accuracy: 0.8764 - 53s/epoch - 137ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.87640 to 0.88050, saving model to best_model.hdf5
# 390/390 - 53s - loss: 0.4126 - accuracy: 0.8508 - val_loss: 0.3174 - val_accuracy: 0.8805 - 53s/epoch - 135ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.88050 to 0.88760, saving model to best_model.hdf5
# 390/390 - 70s - loss: 0.3907 - accuracy: 0.8583 - val_loss: 0.2986 - val_accuracy: 0.8876 - 70s/epoch - 180ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.88760 to 0.89090, saving model to best_model.hdf5
# 390/390 - 86s - loss: 0.3733 - accuracy: 0.8641 - val_loss: 0.2914 - val_accuracy: 0.8909 - 86s/epoch - 222ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.89090
# 390/390 - 101s - loss: 0.3668 - accuracy: 0.8646 - val_loss: 0.3056 - val_accuracy: 0.8845 - 101s/epoch - 258ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.89090 to 0.89580, saving model to best_model.hdf5
# 390/390 - 89s - loss: 0.3589 - accuracy: 0.8697 - val_loss: 0.2837 - val_accuracy: 0.8958 - 89s/epoch - 228ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy improved from 0.89580 to 0.89980, saving model to best_model.hdf5
# 390/390 - 105s - loss: 0.3441 - accuracy: 0.8742 - val_loss: 0.2707 - val_accuracy: 0.8998 - 105s/epoch - 270ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.89980
# 390/390 - 101s - loss: 0.3324 - accuracy: 0.8776 - val_loss: 0.2749 - val_accuracy: 0.8969 - 101s/epoch - 259ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.89980 to 0.90050, saving model to best_model.hdf5
# 390/390 - 111s - loss: 0.3300 - accuracy: 0.8788 - val_loss: 0.2654 - val_accuracy: 0.9005 - 111s/epoch - 285ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.90050 to 0.90410, saving model to best_model.hdf5
# 390/390 - 84s - loss: 0.3166 - accuracy: 0.8829 - val_loss: 0.2615 - val_accuracy: 0.9041 - 84s/epoch - 214ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy improved from 0.90410 to 0.90440, saving model to best_model.hdf5
# 390/390 - 84s - loss: 0.3146 - accuracy: 0.8829 - val_loss: 0.2548 - val_accuracy: 0.9044 - 84s/epoch - 215ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.90440
# 390/390 - 111s - loss: 0.3057 - accuracy: 0.8878 - val_loss: 0.2590 - val_accuracy: 0.9033 - 111s/epoch - 284ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy improved from 0.90440 to 0.90510, saving model to best_model.hdf5
# 390/390 - 109s - loss: 0.3046 - accuracy: 0.8876 - val_loss: 0.2565 - val_accuracy: 0.9051 - 109s/epoch - 279ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.90510
# 390/390 - 65s - loss: 0.3038 - accuracy: 0.8876 - val_loss: 0.2509 - val_accuracy: 0.9043 - 65s/epoch - 166ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy improved from 0.90510 to 0.91000, saving model to best_model.hdf5
# 390/390 - 43s - loss: 0.2943 - accuracy: 0.8926 - val_loss: 0.2381 - val_accuracy: 0.9100 - 43s/epoch - 111ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.91000
# 390/390 - 44s - loss: 0.2915 - accuracy: 0.8931 - val_loss: 0.2494 - val_accuracy: 0.9039 - 44s/epoch - 112ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy improved from 0.91000 to 0.91300, saving model to best_model.hdf5
# 390/390 - 46s - loss: 0.2838 - accuracy: 0.8947 - val_loss: 0.2359 - val_accuracy: 0.9130 - 46s/epoch - 117ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.91300
# 390/390 - 44s - loss: 0.2838 - accuracy: 0.8948 - val_loss: 0.2365 - val_accuracy: 0.9117 - 44s/epoch - 114ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.91300
# 390/390 - 52s - loss: 0.2828 - accuracy: 0.8957 - val_loss: 0.2353 - val_accuracy: 0.9128 - 52s/epoch - 133ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.91300
# 390/390 - 49s - loss: 0.2764 - accuracy: 0.8973 - val_loss: 0.2355 - val_accuracy: 0.9116 - 49s/epoch - 125ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.91300
# 390/390 - 42s - loss: 0.2718 - accuracy: 0.9002 - val_loss: 0.2487 - val_accuracy: 0.9053 - 42s/epoch - 108ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.91300
# 390/390 - 42s - loss: 0.2703 - accuracy: 0.8998 - val_loss: 0.2411 - val_accuracy: 0.9109 - 42s/epoch - 108ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.91300
# 390/390 - 42s - loss: 0.2692 - accuracy: 0.9010 - val_loss: 0.2355 - val_accuracy: 0.9105 - 42s/epoch - 106ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.91300
# 390/390 - 42s - loss: 0.2656 - accuracy: 0.9017 - val_loss: 0.2339 - val_accuracy: 0.9128 - 42s/epoch - 107ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy improved from 0.91300 to 0.91370, saving model to best_model.hdf5
# 390/390 - 42s - loss: 0.2606 - accuracy: 0.9028 - val_loss: 0.2318 - val_accuracy: 0.9137 - 42s/epoch - 108ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.91370
# 390/390 - 41s - loss: 0.2602 - accuracy: 0.9033 - val_loss: 0.2411 - val_accuracy: 0.9110 - 41s/epoch - 106ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.91370
# 390/390 - 42s - loss: 0.2599 - accuracy: 0.9042 - val_loss: 0.2730 - val_accuracy: 0.8963 - 42s/epoch - 107ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy improved from 0.91370 to 0.91850, saving model to best_model.hdf5
# 390/390 - 42s - loss: 0.2585 - accuracy: 0.9036 - val_loss: 0.2220 - val_accuracy: 0.9185 - 42s/epoch - 108ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.91850
# 390/390 - 41s - loss: 0.2531 - accuracy: 0.9072 - val_loss: 0.2317 - val_accuracy: 0.9137 - 41s/epoch - 106ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.91850
# 390/390 - 42s - loss: 0.2494 - accuracy: 0.9065 - val_loss: 0.2304 - val_accuracy: 0.9156 - 42s/epoch - 107ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.91850
# 390/390 - 42s - loss: 0.2487 - accuracy: 0.9071 - val_loss: 0.2334 - val_accuracy: 0.9122 - 42s/epoch - 107ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.91850
# 390/390 - 42s - loss: 0.2508 - accuracy: 0.9069 - val_loss: 0.2364 - val_accuracy: 0.9109 - 42s/epoch - 109ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.91850
# 390/390 - 44s - loss: 0.2488 - accuracy: 0.9084 - val_loss: 0.2307 - val_accuracy: 0.9130 - 44s/epoch - 112ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.91850
# 390/390 - 39s - loss: 0.2444 - accuracy: 0.9101 - val_loss: 0.2280 - val_accuracy: 0.9166 - 39s/epoch - 100ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.91850
# 390/390 - 39s - loss: 0.2429 - accuracy: 0.9102 - val_loss: 0.2328 - val_accuracy: 0.9156 - 39s/epoch - 99ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.91850
# 390/390 - 36s - loss: 0.2454 - accuracy: 0.9070 - val_loss: 0.2531 - val_accuracy: 0.9060 - 36s/epoch - 92ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.91850
# 390/390 - 37s - loss: 0.2416 - accuracy: 0.9096 - val_loss: 0.2236 - val_accuracy: 0.9149 - 37s/epoch - 94ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.91850
# 390/390 - 36s - loss: 0.2410 - accuracy: 0.9123 - val_loss: 0.2380 - val_accuracy: 0.9127 - 36s/epoch - 92ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy improved from 0.91850 to 0.91930, saving model to best_model.hdf5
# 390/390 - 38s - loss: 0.2364 - accuracy: 0.9126 - val_loss: 0.2193 - val_accuracy: 0.9193 - 38s/epoch - 96ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.91930
# 390/390 - 36s - loss: 0.2411 - accuracy: 0.9107 - val_loss: 0.2169 - val_accuracy: 0.9170 - 36s/epoch - 93ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.91930
# 390/390 - 36s - loss: 0.2383 - accuracy: 0.9112 - val_loss: 0.2401 - val_accuracy: 0.9116 - 36s/epoch - 93ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.91930
# 390/390 - 38s - loss: 0.2374 - accuracy: 0.9127 - val_loss: 0.2223 - val_accuracy: 0.9184 - 38s/epoch - 98ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy improved from 0.91930 to 0.92000, saving model to best_model.hdf5
# 390/390 - 37s - loss: 0.2328 - accuracy: 0.9132 - val_loss: 0.2215 - val_accuracy: 0.9200 - 37s/epoch - 94ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.92000
# 390/390 - 37s - loss: 0.2286 - accuracy: 0.9128 - val_loss: 0.2226 - val_accuracy: 0.9198 - 37s/epoch - 94ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy improved from 0.92000 to 0.92100, saving model to best_model.hdf5
# 390/390 - 38s - loss: 0.2283 - accuracy: 0.9157 - val_loss: 0.2205 - val_accuracy: 0.9210 - 38s/epoch - 99ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.92100
# 390/390 - 36s - loss: 0.2306 - accuracy: 0.9145 - val_loss: 0.2348 - val_accuracy: 0.9141 - 36s/epoch - 93ms/step

# %% [markdown]
#     Loss function —This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.
#     Optimizer —This is how the model is updated based on the data it sees and its loss function.
#     Metrics —Used to monitor the training and testing steps. The following example uses accuracy, the fraction of the images that are correctly classified.

# %%
plt.plot(hist.history['accuracy'],label='Train Accuracy')
plt.plot(hist.history['val_accuracy'],label='Validation Accuracy')
plt.legend()
plt.title('Accuracy evolution')
plt.show()

# %%
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss evolution')
# Out:
# Text(0.5, 1.0, 'Loss evolution')

# %%
train_loss, train_acc = model.evaluate(train_images, train_labels)
val_loss, val_acc = model.evaluate(valid_images, valid_labels)
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Train accuracy:', train_acc, ' \tTrain loss: ', train_loss)
print('Validation accuracy:', val_acc, ' \tValidation loss: ', val_loss)
print('Test accuracy:', test_acc, ' \tTest loss: ', test_loss)
# Out:
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1345 - accuracy: 0.9503
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2348 - accuracy: 0.9141
# 313/313 [==============================] - 2s 7ms/step - loss: 0.2506 - accuracy: 0.9132
# Train accuracy: 0.9502800107002258  	Train loss:  0.13452543318271637
# Validation accuracy: 0.9140999913215637  	Validation loss:  0.2348102480173111
# Test accuracy: 0.9132000207901001  	Test loss:  0.25059038400650024

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)
  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
predictions = model.predict(test_images)
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 3s 9ms/step

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(model.predict(test_images), axis=-1)
print(classification_report(test_labels, y_pred, target_names = class_names))
# Out:
# 313/313 [==============================] - 2s 8ms/step
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.89      0.84      0.87      1000
#      Trouser       0.99      0.98      0.99      1000
#     Pullover       0.91      0.79      0.85      1000
#        Dress       0.88      0.95      0.91      1000
#         Coat       0.84      0.86      0.85      1000
#       Sandal       0.99      0.99      0.99      1000
#        Shirt       0.73      0.79      0.76      1000
#      Sneaker       0.96      0.98      0.97      1000
#          Bag       0.99      0.98      0.98      1000
#   Ankle boot       0.98      0.96      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.92      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000
